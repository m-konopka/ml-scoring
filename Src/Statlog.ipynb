# %%
import pandas as pd

# %%
german_data_colnames = [
    "chk_acct", "duration", "credit_his", "purpose", 
    "amount", "saving_acct", "present_emp", "installment_rate", "sex", "other_debtor", 
    "present_resid", "property", "age", "other_install", "housing", "n_credits", 
    "job", "n_people", "telephone", "foreign", "response"
]

df = pd.read_csv('..\\Data\\Statlog\\german.data', header=None, delimiter=r"\s+", names=german_data_colnames)
df['GOOD'] = df['response']-1 
df = df.drop(['response'], axis=1)
df
# Out:
#     chk_acct  duration credit_his purpose  amount saving_acct present_emp  \
# 0        A11         6        A34     A43    1169         A65         A75
# 1        A12        48        A32     A43    5951         A61         A73
# 2        A14        12        A34     A46    2096         A61         A74
# 3        A11        42        A32     A42    7882         A61         A74
# 4        A11        24        A33     A40    4870         A61         A73
# ..       ...       ...        ...     ...     ...         ...         ...
# 995      A14        12        A32     A42    1736         A61         A74
# 996      A11        30        A32     A41    3857         A61         A73
# 997      A14        12        A32     A43     804         A61         A75
# 998      A11        45        A32     A43    1845         A61         A73
# 999      A12        45        A34     A41    4576         A62         A71
#
#      installment_rate  sex other_debtor  ...  property age  other_install  \
# 0                   4  A93         A101  ...      A121  67           A143
# 1                   2  A92         A101  ...      A121  22           A143
# 2                   2  A93         A101  ...      A121  49           A143
# 3                   2  A93         A103  ...      A122  45           A143
# 4                   3  A93         A101  ...      A124  53           A143
# ..                ...  ...          ...  ...       ...  ..            ...
# 995                 3  A92         A101  ...      A121  31           A143
# 996                 4  A91         A101  ...      A122  40           A143
# 997                 4  A93         A101  ...      A123  38           A143
# 998                 4  A93         A101  ...      A124  23           A143
# 999                 3  A93         A101  ...      A123  27           A143
#
#     housing n_credits   job n_people  telephone foreign GOOD
# 0      A152         2  A173        1       A192    A201    0
# 1      A152         1  A173        1       A191    A201    1
# 2      A152         1  A172        2       A191    A201    0
# 3      A153         1  A173        2       A191    A201    0
# 4      A153         2  A173        2       A191    A201    1
# ..      ...       ...   ...      ...        ...     ...  ...
# 995    A152         1  A172        1       A191    A201    0
# 996    A152         1  A174        1       A192    A201    0
# 997    A152         1  A173        1       A191    A201    0
# 998    A153         1  A173        1       A192    A201    1
# 999    A152         1  A173        1       A191    A201    0
#
# [1000 rows x 21 columns]
